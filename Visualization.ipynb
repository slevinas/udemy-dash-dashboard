# %%
# First look at the data...

electricity = pd.read_csv('~/Downloads/electricity.csv')
print(electricity.shape)
print('------------')
print(electricity.info())
print('------------')
for colName in list(electricity.columns):
    print(colName)
    
print('------------') 
print(electricity.head(5))
print('------------')
# Out:
# (1530, 3)
# ------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1530 entries, 0 to 1529
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               1530 non-null   int64
#  1   US_State           1530 non-null   object
#  2   Residential Price  1530 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 36.0+ KB
# None
# ------------
# Year
# US_State
# Residential Price
# ------------
#    Year US_State  Residential Price
# 0  2019       AK              22.92
# 1  2019       AL              12.53
# 2  2019       AR               9.80
# 3  2019       AZ              12.43
# 4  2019       CA              19.15
# ------------

# %%
## Sort values = order by 
#DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)

df.sort_values(by='col1', ascending=False)
df.sort_values(by=['col1', 'col2'])

# %%
year_min = electricity['Year'].min()
year_max = electricity['Year'].max()
print()
print('year_min: ',year_min)
print('------------')
print('year_max: ',year_max)
print('------------')
# Out:
# year_min:  1990
# ------------
# year_max:  2019
# ------------

# %%
marks={i: str(i) for i in range(
                        year_min, year_max+1)}

print(marks)
# Out:
# {1990: '1990', 1991: '1991', 1992: '1992', 1993: '1993', 1994: '1994', 1995: '1995', 1996: '1996', 1997: '1997', 1998: '1998', 1999: '1999', 2000: '2000', 2001: '2001', 2002: '2002', 2003: '2003', 2004: '2004', 2005: '2005', 2006: '2006', 2007: '2007', 2008: '2008', 2009: '2009', 2010: '2010', 2011: '2011', 2012: '2012', 2013: '2013', 2014: '2014', 2015: '2015', 2016: '2016', 2017: '2017', 2018: '2018', 2019: '2019'}

# %%
print(electricity.sort_values(by=['Year', 'US_State'],ascending=False))
# Out:
#       Year US_State  Residential Price
# 50    2019       WY              11.18
# 49    2019       WV              11.25
# 48    2019       WI              14.18
# 47    2019       WA               9.71
# 46    2019       VT              17.71
# 45    2019       VA              12.07
# 44    2019       UT              10.40
# 43    2019       TX              11.76
# 42    2019       TN              10.87
# 41    2019       SD              11.55
# 40    2019       SC              12.99
# 39    2019       RI              21.73
# 38    2019       PA              13.80
# 37    2019       OR              11.01
# 36    2019       OK              10.21
# 35    2019       OH              12.38
# 34    2019       NY              17.94
# 33    2019       NV              12.00
# 32    2019       NM              12.51
# 31    2019       NJ              15.85
# 30    2019       NH              20.05
# 29    2019       NE              10.77
# 28    2019       ND              10.30
# ...

# %%
electricity = pd.read_csv('~/Downloads/electricity.csv')

min_year = electricity['Year'].min()
max_year = electricity['Year'].max()

filtered_electricity = electricity[(
        electricity['Year'] >= selected_years[0] & electricity['Year'] <= selected_years[1])]

    avg_price_electricity = filtered_electricity.groupby('US_State')['Residential Price'].reset_index().mean()

avg_price_electricity = filtered_electricity.groupby('US_State')['Residential Price'].reset_index().mean()

# %%
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Apples", "Oranges", "Bananas"],
    "Amount": [4, 1, 2, 2, 4, 5],
    "City": ["SF", "SF", "SF", "Montreal", "Montreal", "kkk"]
})
print(df)
# Out:
#      Fruit  Amount      City
# 0   Apples       4        SF
# 1  Oranges       1        SF
# 2  Bananas       2        SF
# 3   Apples       2  Montreal
# 4  Oranges       4  Montreal
# 5  Bananas       5       kkk

# %%
# # Standard plotly imports
# import plotly.plotly as py
# import plotly.graph_objs as go
# from plotly.offline import iplot, init_notebook_mode
# # Using plotly + cufflinks in offline mode
# import cufflinks
# cufflinks.go_offline(connected=True)
# init_notebook_mode(connected=True)

#print(dfnow.style.set_properties(**{'text-align': 'left'}))
#display(dfnow.style.set_properties(**{'text-align': 'left'}))



log_file_loc='./world_happiness.csv'

df_world_happines = pd.read_csv(log_file_loc)
df_world_happines.head()
print()
print(df_world_happines.info())
# Out:
#      country                     region  happiness_rank  happiness_score  year
# 0  Australia  Australia and New Zealand              10            7.284  2015
# 1  Australia  Australia and New Zealand               9            7.313  2016
# 2  Australia  Australia and New Zealand              10            7.284  2017
# 3  Australia  Australia and New Zealand              10            7.272  2018
# 4  Australia  Australia and New Zealand              11            7.228  2019
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1088 entries, 0 to 1087
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          1088 non-null   object
#  1   region           1088 non-null   object
#  2   happiness_rank   1088 non-null   int64
#  3   happiness_score  1088 non-null   float64
#  4   year             1088 non-null   int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 42.6+ KB
# None

# %%
happines = df_world_happines.copy()

# %%
print(happines[happines['region'] == 'North America'])
print()
print(type(happines[happines['region'] == 'North America']))
# Out:
#            country         region  happiness_rank  happiness_score  year
# 426         Canada  North America               5           7.4270  2015
# 427         Canada  North America               6           7.4040  2016
# 428         Canada  North America               7           7.3160  2017
# 429         Canada  North America               7           7.3280  2018
# 430         Canada  North America               9           7.2780  2019
# 431         Canada  North America              10           7.2321  2020
# 432  United States  North America              15           7.1190  2015
# 433  United States  North America              13           7.1040  2016
# 434  United States  North America              14           6.9930  2017
# 435  United States  North America              18           6.8860  2018
# 436  United States  North America              19           6.8920  2019
# 437  United States  North America              17           6.9396  2020
# ...

# %%
pwd
# Out:
# '/Users/sagilevinas/Desktop/tutorials/dash-udemy-course'

# %%
#happines = df_world_happines.copy()
filtered_happines = happines[happines['region'] == 'North America']
filtered_happines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 426 to 967
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          16 non-null     object
#  1   region           16 non-null     object
#  2   happiness_rank   16 non-null     int64
#  3   happiness_score  16 non-null     float64
#  4   year             16 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 768.0+ bytes

# %%
print(filtered_happines)
# Out:
#            country         region  happiness_rank  happiness_score  year
# 426         Canada  North America               5           7.4270  2015
# 427         Canada  North America               6           7.4040  2016
# 428         Canada  North America               7           7.3160  2017
# 429         Canada  North America               7           7.3280  2018
# 430         Canada  North America               9           7.2780  2019
# 431         Canada  North America              10           7.2321  2020
# 432  United States  North America              15           7.1190  2015
# 433  United States  North America              13           7.1040  2016
# 434  United States  North America              14           6.9930  2017
# 435  United States  North America              18           6.8860  2018
# 436  United States  North America              19           6.8920  2019
# 437  United States  North America              17           6.9396  2020
# ...

# %%
import mitosheet
mitosheet.sheet(df_world_happines, analysis_to_replay="id-jcjriieyrk")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-jcjriieyrk", "analysisToReplay": null, "code": [], "stepSu…

# %%
print(df_world_happines[df_world_happines['region'] == 'North America'])
# Out:
#            country         region  happiness_rank  happiness_score  year
# 426         Canada  North America               5           7.4270  2015
# 427         Canada  North America               6           7.4040  2016
# 428         Canada  North America               7           7.3160  2017
# 429         Canada  North America               7           7.3280  2018
# 430         Canada  North America               9           7.2780  2019
# 431         Canada  North America              10           7.2321  2020
# 432  United States  North America              15           7.1190  2015
# 433  United States  North America              13           7.1040  2016
# 434  United States  North America              14           6.9930  2017
# 435  United States  North America              18           6.8860  2018
# 436  United States  North America              19           6.8920  2019
# 437  United States  North America              17           6.9396  2020
# ...

# %%
filtered_happines = happiness[happiness['region']==selected_region]

# %%
namerica_df = df_world_happines[df_world_happines['region'] == 'North America']
namerica_df.info()
print()
namerica_df

# %%
# set option display: when set to None it will be to show All Rows
pd.set_option('display.max_rows', None)
print(namerica_df)
# Out:
#            country         region  happiness_rank  happiness_score  year
# 426         Canada  North America               5           7.4270  2015
# 427         Canada  North America               6           7.4040  2016
# 428         Canada  North America               7           7.3160  2017
# 429         Canada  North America               7           7.3280  2018
# 430         Canada  North America               9           7.2780  2019
# 431         Canada  North America              10           7.2321  2020
# 432  United States  North America              15           7.1190  2015
# 433  United States  North America              13           7.1040  2016
# 434  United States  North America              14           6.9930  2017
# 435  United States  North America              18           6.8860  2018
# 436  United States  North America              19           6.8920  2019
# 437  United States  North America              17           6.9396  2020
# ...

# %%
import mitosheet
mitosheet.sheet(namerica_df, analysis_to_replay="id-ensbawpifj")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-ensbawpifj", "analysisToReplay": null, "code": [], "stepSu…

# %%
print(df_world_happines.head(5))
print(df_world_happines['country'].value_counts())
# Out:
#      country                     region  happiness_rank  happiness_score  year
# 0  Australia  Australia and New Zealand              10            7.284  2015
# 1  Australia  Australia and New Zealand               9            7.313  2016
# 2  Australia  Australia and New Zealand              10            7.284  2017
# 3  Australia  Australia and New Zealand              10            7.272  2018
# 4  Australia  Australia and New Zealand              11            7.228  2019
# Australia         8
# Gabon             8
# Benin             8
# Botswana          8
# Burkina Faso      8
#                  ..
# Colombia          8
# Chile             8
# Brazil            8
# Bolivia           8
# United Kingdom    8
# Name: country, Length: 136, dtype: int64

# %%
print(df_world_happines['country'].value_counts().sort_index(ascending=True))
# Out:
# Afghanistan    8
# Albania        8
# Algeria        8
# Argentina      8
# Armenia        8
#               ..
# Venezuela      8
# Vietnam        8
# Yemen          8
# Zambia         8
# Zimbabwe       8
# Name: country, Length: 136, dtype: int64

# %%
print(df_world_happines['country'].value_counts().sort_index(ascending=False))
# Out:
# Zimbabwe       8
# Zambia         8
# Yemen          8
# Vietnam        8
# Venezuela      8
#               ..
# Armenia        8
# Argentina      8
# Algeria        8
# Albania        8
# Afghanistan    8
# Name: country, Length: 136, dtype: int64

# %%
import os
#from PIL import Image               # to load images
#from IPython.display import display # to display images



#file=os.listdir('images/') # = ls "command"
#fdir=os.getcwd() + "/testfolder" # = pwd "command"

print(os.getcwd())
print()
print(os.listdir(os.getcwd()))
# Out:
# /Users/sagilevinas/Desktop/VT_mar22/projects/devop/vt-architecture-plus-modernization-planning/jupyter/by_subject/Supportive
#
# ['Visualization.ipynb', 'Python-interactice-dashboard-course', '.ipynb_checkpoints', 'Data_Exploration']

# %%
# Out:
# '/Users/sagilevinas/Desktop/VT_mar22/projects/devop/vt-architecture-plus-modernization-planning/jupyter/by_subject/Supportive'

# %%
# plotly standard imports
import plotly.graph_objs as go
import chart_studio.plotly as py

# Cufflinks wrapper on plotly
import cufflinks

# Data science imports
import pandas as pd
import numpy as np

# Options for pandas
pd.options.display.max_columns = 30

# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
# We'll be using plotly + cufflinks in offline mode. We will also set the global cufflinks theme to pearl. Later we'll take a look at the other theme options.

from plotly.offline import iplot

cufflinks.go_offline()

# Set global theme
cufflinks.set_config_file(world_readable=True, theme="pearl")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126 entries, 119 to 2
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   claps                      126 non-null    int64
#  1   days_since_publication     126 non-null    float64
#  2   fans                       126 non-null    int64
#  3   link                       126 non-null    object
#  4   num_responses              126 non-null    int64
#  5   publication                126 non-null    object
#  6   published_date             126 non-null    datetime64[ns]
#  7   read_ratio                 126 non-null    float64
#  8   read_time                  126 non-null    int64
#  9   reads                      126 non-null    int64
#  10  started_date               126 non-null    datetime64[ns]
#  11  tags                       126 non-null    object
#  12  text                       126 non-null    object
# ...

# %%
# After importing cufflinks, plotly plots can be made using df.iplot() and then specifying parameters. This is a great replacement for matplotlib!

# Data
# We are using my medium article statistics data. See this article for how to use your own Medium data! Here is the toolkit used to gather the stats.


df = pd.read_parquet(
    "https://github.com/WillKoehrsen/Data-Analysis/blob/master/plotly/data/medium_data_2019_01_06?raw=true"
)
df.head(3)
# Out:
#      claps  days_since_publication  fans  \
# 119      2              574.858594     2
# 118     18              567.540639     3
# 121     50              554.920762    19
#
#                                                   link  num_responses  \
# 119  https://medium.com/p/screw-the-environment-but...              0
# 118  https://medium.com/p/the-vanquishing-of-war-pl...              0
# 121  https://medium.com/p/capstone-project-mercedes...              0
#
#     publication      published_date  read_ratio  read_time  reads  \
# 119        None 2017-06-10 14:25:00       41.98          7     68
# 118        None 2017-06-17 22:02:00       32.93         14     54
# 121        None 2017-06-30 12:55:00       20.19         42    215
#
#            started_date                                           tags  \
# 119 2017-06-10 14:24:00                    [Climate Change, Economics]
# 118 2017-06-17 22:02:00  [Climate Change, Humanity, Optimism, History]
# ...

# %%
#df['claps'].value_counts(ascending=False)
df.loc(['claps']
# Out:
# 119     2
# 118    18
# 121    50
# 122     0
# Name: claps, dtype: int64

# %%
df["claps"].iplot(
    kind="hist",
    bins=30,
    xTitle="claps",
    linecolor="black",
    yTitle="count",
    title="Claps Distribution",
)

# %%
pwd
# Out:
# '/Users/sagilevinas/Desktop/VT_mar22/projects/devop/vt-architecture-plus-modernization-planning/jupyter/by_subject/Supportive'

# %%
# df[['time_started', 'time_published']].iplot(
#     kind='hist',
#     histnorm='percent',
#     barmode='overlay',
#     xTitle='Time of Day',
#     yTitle='(%) of Articles',
#     title='Time Started and Time Published')


# Resample to monthly frequency and plot 
df2 = df[['views','reads','published_date']].\
         set_index('published_date').\
         resample('M').mean()
df2.iplot(kind='bar', xTitle='Date', yTitle='Average',
    title='Monthly Average Views and Reads')

# %%
df.pivot(columns='publication', values='fans').iplot(
        kind='box',
        yTitle='fans',
        title='Fans Distribution by Publication')

# %%
import plotly.figure_factory as ff
figure = ff.create_scatterplotmatrix(
    df[['claps', 'publication', 'views',      
        'read_ratio','word_count']],
    diag='histogram',
    index='publication')
